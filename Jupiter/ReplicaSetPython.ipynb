# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 82.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 33.9 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient


client = MongoClient("mongodb://mongo1:27017,mongo2:27018,mongo3:27019/?replicaSet=rs0")

db = client["scuola"]
collection = db["studenti"]

student = {"nome": "Laura", "corso": "Data Science", "voto": 30}
collection.insert_one(student)

for doc in collection.find():
    print(doc)

collection.update_one({"nome": "Laura"}, {"$set": {"voto": 31}})

client.close()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-3527580381.py in <cell line: 0>()
#       8
#       9 student = {"nome": "Laura", "corso": "Data Science", "voto": 30}
# ---> 10 collection.insert_one(student)
#      11
#      12 for doc in collection.find():
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     889         write_concern = self._write_concern_for(session)
#     890         return InsertOneResult(
# --> 891             self._insert_one(
#     892                 document,
#     893                 ordered=True,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     829             _check_write_command_response(result)
# ...
